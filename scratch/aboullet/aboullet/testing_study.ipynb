# %%
import neuralset

# %%
from studies import Boullet2026Petit

# %%
path = "/Users/augustin.boullet/ownCloud/1_These_de_Science/0_Raw_data_EEG/4_Petit_Prince/listen_eeg_pilote_khaled/260504"
study = Boullet2026Petit(path=path)

events = study.run()
# Out:
# ---------------------------------------------------------------------------
# ValidationError                           Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 study = Boullet2026Petit()
#       2
#       3 events = study.run()
#
# File ~/.venv/neuroai/lib/python3.12/site-packages/exca/helpers.py:399, in DiscriminatedModel.__init__(self, **kwargs)
#     397 def __init__(self, /, **kwargs: tp.Any) -> None:
#     398     try:
# --> 399         super().__init__(**kwargs)
#     400     except pydantic.ValidationError as e:
#     401         _add_validation_error_note(e)
#
# File ~/.venv/neuroai/lib/python3.12/site-packages/pydantic/main.py:263, in BaseModel.__init__(self, **data)
#     261 # `__tracebackhide__` tells pytest and some other tools to omit this function from tracebacks
#     262 __tracebackhide__ = True
# --> 263 validated_self = self.__pydantic_validator__.validate_python(data, self_instance=self)
#     264 if self is not validated_self:
# ...

# %%
from neuralset.extractors.neuro import MegExtractor

# meg_config = {XXX get in code builder
meg_feature = MegExtractor(**meg_config)

# %% [markdown]
# # Building iter timeline events

# %%
path_r1 = "/Users/augustin.boullet/ownCloud/1_These_de_Science/0_Raw_data_EEG/4_Petit_Prince/listen_eeg_pilote_khaled/260504/run01.fif"

import mne 

raw = mne.io.read_raw_fif(path_r1, preload=True, allow_maxshield='ignore')
# Out:
# /var/folders/mw/mlqz19j52vq727tc7gv3jpz00000gq/T/ipykernel_94771/3427412953.py:5: RuntimeWarning: This filename (/Users/augustin.boullet/ownCloud/1_These_de_Science/0_Raw_data_EEG/4_Petit_Prince/listen_eeg_pilote_khaled/260504/run01.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(path_r1, preload=True, allow_maxshield='ignore')
# /var/folders/mw/mlqz19j52vq727tc7gv3jpz00000gq/T/ipykernel_94771/3427412953.py:5: RuntimeWarning: This file contains raw Internal Active Shielding data. It may be distorted. Elekta recommends it be run through MaxFilter to produce reliable results. Consider closing the file and running MaxFilter on the data.
#   raw = mne.io.read_raw_fif(path_r1, preload=True, allow_maxshield='ignore')

# %%
# %matplotlib qt
raw.plot()
# Out:
# <MNEBrowseFigure size 3024x1714 with 5 Axes>
